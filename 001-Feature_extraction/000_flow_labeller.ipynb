# %%
import os
import pandas as pd

# %%
def find_the_way(path,file_format):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                files_add.append(os.path.join(r, file))  
    return files_add
name_list=find_the_way('./csvs','.csv')
name_list
# Out:
# ['./csvs\\2022_01_03_Active.csv',
#  './csvs\\google_home_mini\\[OS_Service_Detection]Google_Home_Mini.csv',
#  './csvs\\google_home_mini\\[Port_scan]Google_Home_Mini.csv',
#  './csvs\\http\\mirai-httpflooding-1-dec.csv',
#  './csvs\\http\\mirai-httpflooding-2-dec.csv',
#  './csvs\\http\\mirai-httpflooding-3-dec.csv',
#  './csvs\\http\\mirai-httpflooding-4-dec.csv']

# %% [markdown]
# ### Google_Home_Mini

# %%
file_list=['./csvs\\google_home_mini\\[Port_scan]Google_Home_Mini.csv', './csvs\\google_home_mini\\[OS_Service_Detection]Google_Home_Mini.csv']

for  file in file_list:
    df=pd.read_csv(file)
    labeller=df[['Src IP', 'Dst IP', 'Dst Port', 'Protocol']]
    
    # RULES  ##################################################
    label=[]
    for i in labeller.values:
        if i[0]=="192.168.10.30" and i[1]=='192.168.10.5' and i[3] == 'TCP':
                        label.append(1)
        else:label.append(0)
    # RULES  ##################################################
    
    df['Label']=label
    df.to_csv(file,index=False)
    print(df.groupby("Label").size())
# Out:
# Label
# 0    4800
# 1    4066
# dtype: int64
# Label
# 0    70202
# 1    25873
# dtype: int64

# %% [markdown]
# ### HTTP Flood

# %%
name_list=find_the_way('./csvs','http')
name_list
# Out:
# ['./csvs\\http\\mirai-httpflooding-1-dec.csv',
#  './csvs\\http\\mirai-httpflooding-2-dec.csv',
#  './csvs\\http\\mirai-httpflooding-3-dec.csv',
#  './csvs\\http\\mirai-httpflooding-4-dec.csv']

# %%
for  file in name_list:
    df=pd.read_csv(file)
    print(file)
    labeller=df[['Src IP', 'Dst IP', 'Dst Port', 'Protocol']]

    # RULES  ##################################################
    label=[]
    for i in labeller.values:
        if i[1]=='210.89.164.90':
            label.append(1)
        else:label.append(0)
    # RULES  ##################################################
    df['Label']=label
    df.to_csv(file,index=False)
    print(df.groupby("Label").size())
# Out:
# ./csvs\http\mirai-httpflooding-1-dec.csv
# Label
# 0    12999
# 1      764
# dtype: int64
# ./csvs\http\mirai-httpflooding-2-dec.csv
# Label
# 0    105903
# 1      4468
# dtype: int64
# ./csvs\http\mirai-httpflooding-3-dec.csv
# Label
# 0    12999
# 1      764
# dtype: int64
# ./csvs\http\mirai-httpflooding-4-dec.csv
# Label
# 0    105903
# 1      4468
# dtype: int64
