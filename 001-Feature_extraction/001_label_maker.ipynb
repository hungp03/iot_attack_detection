# %%
import os
import pandas as pd

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
folder("pcaps")

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add

# %%
files_add=find_the_way('./','.pcap')
files_add
# Out:
# ['./pcaps\\dos-synflooding-1-dec.pcap',
#  './pcaps\\dos-synflooding-2-dec.pcap',
#  './pcaps\\dos-synflooding-3-dec.pcap',
#  './pcaps\\dos-synflooding-4-dec.pcap',
#  './pcaps\\dos-synflooding-5-dec.pcap',
#  './pcaps\\dos-synflooding-6-dec.pcap',
#  './pcaps\\IoT_Dataset_UDP_DDoS__00002_20180604180217.pcap',
#  './pcaps\\mirai-httpflooding-1-dec.pcap',
#  './pcaps\\mirai-httpflooding-2-dec.pcap',
#  './pcaps\\mirai-httpflooding-3-dec.pcap',
#  './pcaps\\mirai-httpflooding-4-dec.pcap',
#  './pcaps\\[OS_Service_Detection]Google_Home_Mini.pcap',
#  './pcaps\\[Port_scan]Google_Home_Mini.pcap']

# %%
df = pd.read_csv( "dataset_description.csv")
df
# Out:
#     No                                        File Name  \
# 0    1                       dos-synflooding-1-dec.pcap
# 1    2                       dos-synflooding-2-dec.pcap
# 2    3                       dos-synflooding-3-dec.pcap
# 3    4                       dos-synflooding-4-dec.pcap
# 4    5                       dos-synflooding-5-dec.pcap
# 5    6                       dos-synflooding-6-dec.pcap
# 6    7                    mirai-httpflooding-1-dec.pcap
# 7    8                    mirai-httpflooding-2-dec.pcap
# 8    9                    mirai-httpflooding-3-dec.pcap
# 9   10                    mirai-httpflooding-4-dec.pcap
# 10  11  IoT_Dataset_UDP_DDoS__00002_20180604180217.pcap
# 11  12      [OS_Service_Detection]Google_Home_Mini.pcap
# 12  13                 [Port_scan]Google_Home_Mini.pcap
#
#                    Category   Sub-category  \
# 0   Denial of Service (DoS)   SYN Flooding
# 1   Denial of Service (DoS)   SYN Flooding
# 2   Denial of Service (DoS)   SYN Flooding
# 3   Denial of Service (DoS)   SYN Flooding
# 4   Denial of Service (DoS)   SYN Flooding
# 5   Denial of Service (DoS)   SYN Flooding
# 6              Mirai Botnet  HTTP Flooding
# 7              Mirai Botnet  HTTP Flooding
# 8              Mirai Botnet  HTTP Flooding
# 9              Mirai Botnet  HTTP Flooding
# 10                      NaN            NaN
# 11                      NaN            NaN
# 12                      NaN            NaN
#
#                                                  Rule
# 0   ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 a...
# 1   ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 a...
# 2   ip.src == 111.0.0.0/8 and tcp.flags.syn == 1 a...
# 3   ip.dst == 192.168.0.24 and tcp.flags.syn == 1 ...
# 4   ip.dst == 192.168.0.24 and tcp.flags.syn == 1 ...
# 5   ip.dst == 192.168.0.24 and tcp.flags.syn == 1 ...
# 6                             ip.dst == 210.89.164.90
# 7                             ip.dst == 210.89.164.90
# 8                             ip.dst == 210.89.164.90
# 9                             ip.dst == 210.89.164.90
# 10  (ip.src==192.168.100.147 || ip.src==192.168.10...
# 11  ip.src==192.168.10.30 and ip.dst==192.168.10.5...
# 12  ip.src==192.168.10.30 and ip.dst==192.168.10.5...

# %%
df.columns
# Out:
# Index(['No', 'File Name', 'Category', 'Sub-category', 'Rule'], dtype='object')

# %%
name=df['File Name']
rule=df['Rule']
cat=df['Category']
subcat=df['Sub-category']

# %%
name
# Out:
# 0                          dos-synflooding-1-dec.pcap
# 1                          dos-synflooding-2-dec.pcap
# 2                          dos-synflooding-3-dec.pcap
# 3                          dos-synflooding-4-dec.pcap
# 4                          dos-synflooding-5-dec.pcap
# 5                          dos-synflooding-6-dec.pcap
# 6                       mirai-httpflooding-1-dec.pcap
# 7                       mirai-httpflooding-2-dec.pcap
# 8                       mirai-httpflooding-3-dec.pcap
# 9                       mirai-httpflooding-4-dec.pcap
# 10    IoT_Dataset_UDP_DDoS__00002_20180604180217.pcap
# 11        [OS_Service_Detection]Google_Home_Mini.pcap
# 12                   [Port_scan]Google_Home_Mini.pcap
# Name: File Name, dtype: object

# %%
files_add=find_the_way('./','.pcap')
uzun=len(files_add)
uzun
# Out:
# 13

# %%
for i in range(len(name)):
    add=str(cat[i])+"@"+str(subcat[i])+"_"
    add=add.replace(" ","_")
    command='tshark -Y \"'+str(rule[i])+"\" -r ./pcaps/"+str(name[i])+" -T fields -e frame.number > ./pcaps/attack_"+str(name[i])[:-4]+"csv"
    os.system(command)
    command='tshark -Y \"!('+str(rule[i])+")\" -r ./pcaps/"+str(name[i])+" -T fields -e frame.number > ./pcaps/normal_"+str(name[i])[:-4]+"csv"
    os.system(command)
    files_add=find_the_way('./','.pcap')
    if uzun==len(files_add):    
        print(command,"\n")
    uzun=len(files_add)
# Out:
# tshark -Y "!(ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 and ip.dst == 192.168.0.13 and tcp.dstport == 554 and tcp)" -r ./pcaps/dos-synflooding-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-1-dec.csv
#
# tshark -Y "!(ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 and ip.dst == 192.168.0.13 and tcp.dstport == 554 and tcp)" -r ./pcaps/dos-synflooding-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-2-dec.csv
#
# tshark -Y "!(ip.src == 111.0.0.0/8 and tcp.flags.syn == 1 and ip.dst == 192.168.0.13 and tcp.dstport == 554 and tcp)" -r ./pcaps/dos-synflooding-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-3-dec.csv
#
# tshark -Y "!(ip.dst == 192.168.0.24 and tcp.flags.syn == 1 and ip.src == 111.0.0.0/8 and tcp and tcp.dstport == 19604)" -r ./pcaps/dos-synflooding-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-4-dec.csv
#
# tshark -Y "!(ip.dst == 192.168.0.24 and tcp.flags.syn == 1 and ip.src == 111.0.0.0/8 and tcp and tcp.dstport == 19604)" -r ./pcaps/dos-synflooding-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-5-dec.csv
#
# tshark -Y "!(ip.dst == 192.168.0.24 and tcp.flags.syn == 1 and ip.src == 111.0.0.0/8 and tcp and tcp.dstport == 19604)" -r ./pcaps/dos-synflooding-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-6-dec.csv
#
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-1-dec.csv
#
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-2-dec.csv
#
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-3-dec.csv
#
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-4-dec.csv
#
# tshark -Y "!((ip.src==192.168.100.147 || ip.src==192.168.100.148  || ip.src==192.168.100.149  || ip.src==192.168.100.150))" -r ./pcaps/IoT_Dataset_UDP_DDoS__00002_20180604180217.pcap -T fields -e frame.number > ./pcaps/normal_IoT_Dataset_UDP_DDoS__00002_20180604180217.csv
#
# tshark -Y "!(ip.src==192.168.10.30 and ip.dst==192.168.10.5 and (tcp.flags.syn == 1 ))" -r ./pcaps/[OS_Service_Detection]Google_Home_Mini.pcap -T fields -e frame.number > ./pcaps/normal_[OS_Service_Detection]Google_Home_Mini.csv
#
# tshark -Y "!(ip.src==192.168.10.30 and ip.dst==192.168.10.5 and (tcp.flags.syn == 1 ))" -r ./pcaps/[Port_scan]Google_Home_Mini.pcap -T fields -e frame.number > ./pcaps/normal_[Port_scan]Google_Home_Mini.csv

# %%
name_list=find_the_way('./pcaps','.csv')
name_list
# Out:
# ['./pcaps\\attack_dos-synflooding-1-dec.csv',
#  './pcaps\\attack_dos-synflooding-2-dec.csv',
#  './pcaps\\attack_dos-synflooding-3-dec.csv',
#  './pcaps\\attack_dos-synflooding-4-dec.csv',
#  './pcaps\\attack_dos-synflooding-5-dec.csv',
#  './pcaps\\attack_dos-synflooding-6-dec.csv',
#  './pcaps\\attack_IoT_Dataset_UDP_DDoS__00002_20180604180217.csv',
#  './pcaps\\attack_mirai-httpflooding-1-dec.csv',
#  './pcaps\\attack_mirai-httpflooding-2-dec.csv',
#  './pcaps\\attack_mirai-httpflooding-3-dec.csv',
#  './pcaps\\attack_mirai-httpflooding-4-dec.csv',
#  './pcaps\\attack_[OS_Service_Detection]Google_Home_Mini.csv',
#  './pcaps\\attack_[Port_scan]Google_Home_Mini.csv',
#  './pcaps\\normal_dos-synflooding-1-dec.csv',
#  './pcaps\\normal_dos-synflooding-2-dec.csv',
#  './pcaps\\normal_dos-synflooding-3-dec.csv',
#  './pcaps\\normal_dos-synflooding-4-dec.csv',
#  './pcaps\\normal_dos-synflooding-5-dec.csv',
#  './pcaps\\normal_dos-synflooding-6-dec.csv',
#  './pcaps\\normal_IoT_Dataset_UDP_DDoS__00002_20180604180217.csv',
#  './pcaps\\normal_mirai-httpflooding-1-dec.csv',
#  './pcaps\\normal_mirai-httpflooding-2-dec.csv',
#  './pcaps\\normal_mirai-httpflooding-3-dec.csv',
#  './pcaps\\normal_mirai-httpflooding-4-dec.csv',
#  './pcaps\\normal_[OS_Service_Detection]Google_Home_Mini.csv',
#  './pcaps\\normal_[Port_scan]Google_Home_Mini.csv']

# %%
label_files=[]
for i in name_list:
    temp=i[15:]
    print(temp)
    if temp not in label_files:
        label_files.append(temp)
# Out:
# dos-synflooding-1-dec.csv
# dos-synflooding-2-dec.csv
# dos-synflooding-3-dec.csv
# dos-synflooding-4-dec.csv
# dos-synflooding-5-dec.csv
# dos-synflooding-6-dec.csv
# IoT_Dataset_UDP_DDoS__00002_20180604180217.csv
# mirai-httpflooding-1-dec.csv
# mirai-httpflooding-2-dec.csv
# mirai-httpflooding-3-dec.csv
# mirai-httpflooding-4-dec.csv
# [OS_Service_Detection]Google_Home_Mini.csv
# [Port_scan]Google_Home_Mini.csv
# dos-synflooding-1-dec.csv
# dos-synflooding-2-dec.csv
# dos-synflooding-3-dec.csv
# dos-synflooding-4-dec.csv
# dos-synflooding-5-dec.csv
# dos-synflooding-6-dec.csv
# IoT_Dataset_UDP_DDoS__00002_20180604180217.csv
# mirai-httpflooding-1-dec.csv
# mirai-httpflooding-2-dec.csv
# mirai-httpflooding-3-dec.csv
# mirai-httpflooding-4-dec.csv
# [OS_Service_Detection]Google_Home_Mini.csv
# [Port_scan]Google_Home_Mini.csv

# %%
for i in label_files:

    name=find_the_way('./pcaps',i)
    print(name)

    dfA = pd.read_csv(name[0], header=None)
    dfA=dfA.rename(columns={0: "PacketNumber"})
    dfA["Label"]=[1] * len(dfA)
    
    
    dfN = pd.read_csv(name[1], header=None)
    dfN=dfN.rename(columns={0: "PacketNumber"})    
    dfN["Label"]=[0] * len(dfN) 

    df = pd.concat([dfA,dfN])
    df=df.sort_values('PacketNumber')
    df.to_csv(f"./pcaps/{i}",  index=False)
    print(i,df.groupby("Label").size(),"\n\n\n")
    os.remove(f"./pcaps\\normal_{i}")
    os.remove(f"./pcaps\\attack_{i}")
# Out:
# ['./pcaps\\attack_dos-synflooding-1-dec.csv', './pcaps\\normal_dos-synflooding-1-dec.csv']
# dos-synflooding-1-dec.csv Label
# 0    22085
# 1    18703
# dtype: int64
#
#
#
# ['./pcaps\\attack_dos-synflooding-2-dec.csv', './pcaps\\normal_dos-synflooding-2-dec.csv']
# dos-synflooding-2-dec.csv Label
# 0    22880
# 1    16862
# dtype: int64
#
#
#
# ['./pcaps\\attack_dos-synflooding-3-dec.csv', './pcaps\\normal_dos-synflooding-3-dec.csv']
# dos-synflooding-3-dec.csv Label
# 0    13796
# 1    12538
# dtype: int64
#
#
#
# ['./pcaps\\attack_dos-synflooding-4-dec.csv', './pcaps\\normal_dos-synflooding-4-dec.csv']
# dos-synflooding-4-dec.csv Label
# 0    5869
# 1    4692
# dtype: int64
#
#
#
# ['./pcaps\\attack_dos-synflooding-5-dec.csv', './pcaps\\normal_dos-synflooding-5-dec.csv']
# dos-synflooding-5-dec.csv Label
# 0    5818
# 1    5548
# dtype: int64
#
#
#
# ['./pcaps\\attack_dos-synflooding-6-dec.csv', './pcaps\\normal_dos-synflooding-6-dec.csv']
# dos-synflooding-6-dec.csv Label
# 0    6615
# 1    6303
# dtype: int64
#
#
#
# ['./pcaps\\attack_IoT_Dataset_UDP_DDoS__00002_20180604180217.csv', './pcaps\\normal_IoT_Dataset_UDP_DDoS__00002_20180604180217.csv']
# IoT_Dataset_UDP_DDoS__00002_20180604180217.csv Label
# 0       8797
# 1    2633075
# dtype: int64
#
#
#
# ['./pcaps\\attack_mirai-httpflooding-1-dec.csv', './pcaps\\normal_mirai-httpflooding-1-dec.csv']
# mirai-httpflooding-1-dec.csv Label
# 0    13000
# 1      764
# dtype: int64
#
#
#
# ['./pcaps\\attack_mirai-httpflooding-2-dec.csv', './pcaps\\normal_mirai-httpflooding-2-dec.csv']
# mirai-httpflooding-2-dec.csv Label
# 0    105915
# 1      4468
# dtype: int64
#
#
#
# ['./pcaps\\attack_mirai-httpflooding-3-dec.csv', './pcaps\\normal_mirai-httpflooding-3-dec.csv']
# mirai-httpflooding-3-dec.csv Label
# 0    13000
# 1      764
# dtype: int64
#
#
#
# ['./pcaps\\attack_mirai-httpflooding-4-dec.csv', './pcaps\\normal_mirai-httpflooding-4-dec.csv']
# mirai-httpflooding-4-dec.csv Label
# 0    105915
# 1      4468
# dtype: int64
#
#
#
# ['./pcaps\\attack_[OS_Service_Detection]Google_Home_Mini.csv', './pcaps\\normal_[OS_Service_Detection]Google_Home_Mini.csv']
# [OS_Service_Detection]Google_Home_Mini.csv Label
# 0    83671
# 1    12426
# dtype: int64
#
#
#
# ['./pcaps\\attack_[Port_scan]Google_Home_Mini.csv', './pcaps\\normal_[Port_scan]Google_Home_Mini.csv']
# [Port_scan]Google_Home_Mini.csv Label
# 0    4818
# 1    4048
# dtype: int64
